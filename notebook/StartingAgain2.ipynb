# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce
from datetime import date
from datetime import datetime

# %%
dental = pd.read_csv('../data/Smileon.2021.10.17.csv', encoding = "latin-1", skiprows=2)
dental.shape
# Out:
# (57860, 184)

# %%
dental.dropna(how='all', axis=1, inplace=True)

# %%
dental.shape
# Out:
# (57860, 130)

# %%
dental.head(5)
# Out:
#    CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0       93115324  SMILE ON 60+ Registration                   NaN
# 1       93115188  SMILE ON 60+ Registration                   NaN
# 2       93115081      SMILE ON 60+ Clinical                   NaN
# 3       93115032      SMILE ON 60+ Clinical                   NaN
# 4       93114968      SMILE ON 60+ Clinical                   NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0      9/30/2021 16:56    9/30/2021 16:57           1    3638169
# 1      9/30/2021 16:53    9/30/2021 16:53           0    4431194
# 2      9/30/2021 16:50    9/30/2021 16:51           1    2941341
# 3      9/30/2021 16:48    9/30/2021 16:49           1    3823933
# 4      9/30/2021 16:46    9/30/2021 16:48           2    3348256
#
#    PhoneWorkerNum   CityName  CountyName  ...  \
# 0          123747     Smyrna  Rutherford  ...
# 1          123747  Nashville    Davidson  ...
# ...

# %%
dental.dropna(how='all', axis=1, inplace=True)

# %%
dental.shape
# Out:
# (57860, 130)

# %%
dental.info
# Out:
# <bound method DataFrame.info of        CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0           93115324  SMILE ON 60+ Registration                   NaN
# 1           93115188  SMILE ON 60+ Registration                   NaN
# 2           93115081      SMILE ON 60+ Clinical                   NaN
# 3           93115032      SMILE ON 60+ Clinical                   NaN
# 4           93114968      SMILE ON 60+ Clinical                   NaN
# ...              ...                        ...                   ...
# 57855       55627514      SMILE ON 60+ Clinical                   NaN
# 57856       67251452      SMILE ON 60+ Clinical                   NaN
# 57857       53192452  SMILE ON 60+ Registration                   NaN
# 57858       67915561  SMILE ON 60+ Registration                   NaN
# 57859       67251405      SMILE ON 60+ Clinical                   NaN
#
#       CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# ...

# %%
list(dental.columns.values)
# Out:
# ['CallReportNum',
#  'ReportVersion',
#  'LinkedToCallReportNum',
#  'CallDateAndTimeStart',
#  'CallDateAndTimeEnd',
#  'CallLength',
#  'CallerNum',
#  'PhoneWorkerNum',
#  'CityName',
#  'CountyName',
#  'StateProvince',
#  'CountryName',
#  'PostalCode',
#  'PhoneType',
#  'ThirdPartyStateProvince',
#  'Narrative',
#  'Feedback',
#  'EnteredByWorkerNum',
#  'EnteredOn',
#  'Reviewed',
#  'FeedbackStatus',
#  'FeedbackFromPhoneWorkerNum',
#  'FeedbackFromPhoneWorkerName',
#  'ReferralsMade',
#  'OrgNum',
#  'SMILE ON 60+ Demographic Information - # of People in Household',
#  'Birth Year',
#  'SMILE ON 60+ Demographic Information - Other Language',
#  'SMILE ON 60+ Notes (Optional) - Notes',
#  'SMILE ON 60+ Oral Care Encounter - 1351 - Quantity',
#  'SMILE ON 60+ Oral Care Encounter - 1354 - Quantity',
#  'SMILE ON 60+ Oral Care Encounter - 2140 - Quantity',
#  'SMILE ON 60+ Oral Care Encounter - 2150 - Quantity',
#  'SMILE ON 60+ Oral Care Encounter - 2160 - Quantity',
# ...

# %%
print(dental.ThirdPartyStateProvince)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 57855    NaN
# 57856    NaN
# 57857    NaN
# 57858    NaN
# 57859    NaN
# Name: ThirdPartyStateProvince, Length: 57860, dtype: object

# %%
dental.drop('ThirdPartyStateProvince', axis=1)
# Out:
#        CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0           93115324  SMILE ON 60+ Registration                   NaN
# 1           93115188  SMILE ON 60+ Registration                   NaN
# 2           93115081      SMILE ON 60+ Clinical                   NaN
# 3           93115032      SMILE ON 60+ Clinical                   NaN
# 4           93114968      SMILE ON 60+ Clinical                   NaN
# ...              ...                        ...                   ...
# 57855       55627514      SMILE ON 60+ Clinical                   NaN
# 57856       67251452      SMILE ON 60+ Clinical                   NaN
# 57857       53192452  SMILE ON 60+ Registration                   NaN
# 57858       67915561  SMILE ON 60+ Registration                   NaN
# 57859       67251405      SMILE ON 60+ Clinical                   NaN
#
#       CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# ...

# %%
#drop multiple columns by adding [] brackets and separating with a comma. Phonetype and OrgNum column are not needed
#dental.drop(['PhoneType', 'OrgNum', 'LinkedToCallReportNum'], axis=1)

# %%
#replace spaces with underscores to be able to read  column names
dental.columns = dental.columns.str.replace(' ','_')

# %%
#List of all column names
list(dental.columns.values)
# Out:
# ['CallReportNum',
#  'ReportVersion',
#  'LinkedToCallReportNum',
#  'CallDateAndTimeStart',
#  'CallDateAndTimeEnd',
#  'CallLength',
#  'CallerNum',
#  'PhoneWorkerNum',
#  'CityName',
#  'CountyName',
#  'StateProvince',
#  'CountryName',
#  'PostalCode',
#  'PhoneType',
#  'ThirdPartyStateProvince',
#  'Narrative',
#  'Feedback',
#  'EnteredByWorkerNum',
#  'EnteredOn',
#  'Reviewed',
#  'FeedbackStatus',
#  'FeedbackFromPhoneWorkerNum',
#  'FeedbackFromPhoneWorkerName',
#  'ReferralsMade',
#  'OrgNum',
#  'SMILE_ON_60+_Demographic_Information_-_#_of_People_in_Household',
#  'Birth_Year',
#  'SMILE_ON_60+_Demographic_Information_-_Other_Language',
#  'SMILE_ON_60+_Notes_(Optional)_-_Notes',
#  'SMILE_ON_60+_Oral_Care_Encounter_-_1351_-_Quantity',
#  'SMILE_ON_60+_Oral_Care_Encounter_-_1354_-_Quantity',
#  'SMILE_ON_60+_Oral_Care_Encounter_-_2140_-_Quantity',
#  'SMILE_ON_60+_Oral_Care_Encounter_-_2150_-_Quantity',
#  'SMILE_ON_60+_Oral_Care_Encounter_-_2160_-_Quantity',
# ...

# %%
#Check if SMILE_ON_60+ Notes column is needed based on output
print(dental['SMILE_ON_60+_Notes_(Optional)_-_Notes'])
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 57855                                                  NaN
# 57856    removed 5213 and 5214 with lab assists and 714...
# 57857                                                  NaN
# 57858                                                  NaN
# 57859    Removed codes 150 274 and 330 as date of servi...
# Name: SMILE_ON_60+_Notes_(Optional)_-_Notes, Length: 57860, dtype: object

# %%
dental.drop(['PhoneType', 'OrgNum', 'LinkedToCallReportNum'], axis=1)
# Out:
#        CallReportNum              ReportVersion CallDateAndTimeStart  \
# 0           93115324  SMILE ON 60+ Registration      9/30/2021 16:56
# 1           93115188  SMILE ON 60+ Registration      9/30/2021 16:53
# 2           93115081      SMILE ON 60+ Clinical      9/30/2021 16:50
# 3           93115032      SMILE ON 60+ Clinical      9/30/2021 16:48
# 4           93114968      SMILE ON 60+ Clinical      9/30/2021 16:46
# ...              ...                        ...                  ...
# 57855       55627514      SMILE ON 60+ Clinical        8/1/2018 8:00
# 57856       67251452      SMILE ON 60+ Clinical       5/31/2018 8:27
# 57857       53192452  SMILE ON 60+ Registration      5/23/2018 14:11
# 57858       67915561  SMILE ON 60+ Registration       5/15/2018 9:06
# 57859       67251405      SMILE ON 60+ Clinical       5/10/2018 8:25
#
#       CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum   CityName  \
# ...

# %%
print(dental.CallerNum)
# Out:
# 0        3638169
# 1        4431194
# 2        2941341
# 3        3823933
# 4        3348256
#           ...
# 57855    2385621
# 57856    2631417
# 57857         -1
# 57858    3239813
# 57859    2631417
# Name: CallerNum, Length: 57860, dtype: int64

# %%
#attempt to view if any duplicates are in CallerNum
#(dental['CallerNum'].duplicated())

# %%
#check for duplicates
# equals true in case of no duplicates, is false when there are duplicates 
dental['CallerNum'].is_unique
# Out:
# False

# %%
#Report number has no duplicate values
dental['CallReportNum'].is_unique
# Out:
# True

# %%
#we can assume that the call report number is a patient
# we need age, gender, race/ethnicity, language, household income, and assistance programs they are enrolled in

# %%
#obtain values in gender
gender = dental['SMILE_ON_60+_Demographic_Information_-_Gender'].value_counts()
print(gender)
# Out:
# Female         35855
# Male           21462
# Transgender       21
# Other              1
# Name: SMILE_ON_60+_Demographic_Information_-_Gender, dtype: int64

# %%
dental[['SMILE_ON_60+_Demographic_Information_-_Gender', '']].apply(pd.Series.value_counts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10076/2319031960.py in <module>
# ----> 1 gender1 = dental['SMILE_ON_60+_Demographic_Information_-_Gender'].unique().value_counts()
#       2 print(gender1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
#Bar Chart for Gender 
# A python dictionary

data = {"Gender":["Female", "Male", "Transgender", "Other"],

        "Number":[35855,21462,21,1]

        };

# Dictionary loaded into a DataFrame       

dental = pd.'SMILE_ON_60+_Demographic_Information_-_Gender'(data=data);

 

# Draw a vertical bar chart

dental.plot.bar(x="Gender", y="Number", rot=70, title="Smile On Gender Information");

plot.show(block=True);

# %%
#obtain values in Race/Ethnicity
#column = 'SMILE_ON_60+_Demographic_Information_-_Race/Ethnicity'
RaceEthnicity = dental['SMILE_ON_60+_Demographic_Information_-_Race/Ethnicity'].value_counts()
print(RaceEthnicity)

# %%
#obtain values of language preferred/needed
#'SMILE_ON_60+_Demographic_Information_-_Preferred_Language/Language_Needed'
language = dental['SMILE_ON_60+_Demographic_Information_-_Preferred_Language/Language_Needed'].value_counts()
print(language)

# %%
#Other languages
'SMILE_ON_60+_Demographic_Information_-_Other_Language'
otherlanguage = dental['SMILE_ON_60+_Demographic_Information_-_Other_Language'].value_counts()
print(otherlanguage)

# %%
#obtain Household Income Level
#'SMILE_ON_60+_Demographic_Information_-_Household_Income_Level'
houseincome = dental['SMILE_ON_60+_Demographic_Information_-_Household_Income_Level'].value_counts()
print(houseincome)

# %%
#Enrolled in OTHER assistance programs, which ones?
# 'SMILE_ON_60+_Demographic_Information_-_What_other_assistance_programs_are_you_on?'
otherprograms = dental['SMILE_ON_60+_Demographic_Information_-_What_other_assistance_programs_are_you_on?'].value_counts()
print(otherprograms)

# %%
#obtain values in age
#dental['Birth_Year'].value_counts()

# %%
#we have a person who is 124 yrs old in this 
# and two people born in the future 5245 and 2041

# %%
#get type of column
print(dental['Birth_Year'].dtypes)

# %%
#print today's date
today = date.today()
print(today)

# %%
#datetime df
currentYear = datetime.now().year
print(currentYear)

# %%
type('Birth_Year')

# %%
#bad data in the column, cannot do anything with it
dental.loc[17417,'Birth_Year']

# %%
#attempted to drop all rows based on '#NUM' - did not work
#dental[dental.Birth_Year != '#NUM']

# %%
#used to delete row 17417 because of #NUM error
#dental = dental.drop(index=17417)

# %%
dental.Birth_Year.loc

# %%
#did not work // 
#currentYear = date.now().year
#print(currentYear)

# %%
#did not work
#age = currentYear - 'Birth_Year'
#print(age)

# %%
list(dental.Birth_Year.values)

# %%
#deleted row 44357 because of #VALUE! error
#dental = dental.drop(index=44357)

# %%
dental = dental.drop(index=44356)

# %%
# attempted to make into int
#dental['Birth_Year'] = dental['Birth_Year'].astype(int)
#dental['Birth_Year'] = pd.to_numeric(dental['Birth_Year'])
dental = dental.drop(dental[dental['Birth_Year'] = '#VALUE!'].index)
print(dental.Birth_Year)
